# %% [markdown]
# # Tutorial 1: A First Estimate
#
# One goal: get a mutual information estimate out of the library, on data whose
# answer we already know, and understand what the number means.
#
# We use **independent and identically distributed** data throughout. Each sample
# is drawn independently, with no temporal ordering, which is the simplest
# possible case and the one setting where "the mutual information of X and Y" is
# a single well-defined number. Real recordings are not like this, and Tutorials 2
# onward deal with that.
#
# This tutorial covers:
#
# 1. Generating data with a known MI, so there is something to check against.
# 2. The single `nmi.run` call, and which number it returns.
# 3. Why a small sample gives an unreliable answer, in both directions.
# 4. Whether you needed a neural estimator at all, which has an honest answer
#    that is sometimes no.

# %% [markdown]
# ## 0. Setup
#
# `SCALE` multiplies sample counts and training epochs. Committed outputs are at
# `SCALE = 1`, which keeps this notebook to a few minutes. Raise it for tighter
# numbers.

# %%
import numpy as np
import matplotlib.pyplot as plt
import neural_mi as nmi

SCALE = 1
np.random.seed(0)

# %% [markdown]
# ## 1. Data with a known answer
#
# `generate_correlated_gaussians` builds two multivariate Gaussians sharing a
# specified amount of information. Because everything is Gaussian, the true MI has
# a closed form, so we can ask the estimator for a number we can grade.
#
# The generator returns `(n_samples, n_dim)`, samples first. We leave `processing`
# unset, which tells the library the data is already in its final form and needs
# no windowing.

# %%
N_SAMPLES = int(5000 * SCALE)
DIM = 5
TRUE_MI = 2.0

x, y = nmi.generators.generate_correlated_gaussians(
    n_samples=N_SAMPLES, dim=DIM, mi=TRUE_MI)

print(f"x: {tuple(x.shape)}   (n_samples, n_channels)")
print(f"y: {tuple(y.shape)}")
print(f"true MI: {TRUE_MI} bits, shared across {DIM} dimensions")
# Out:
# x: (5000, 5)   (n_samples, n_channels)
# y: (5000, 5)
# true MI: 2.0 bits, shared across 5 dimensions

# %%
fig, (ax_s, ax_c) = plt.subplots(1, 2, figsize=(11, 4.4))

ax_s.scatter(np.asarray(x)[:, 0], np.asarray(y)[:, 0], s=6, alpha=0.3,
             color='steelblue')
ax_s.set_xlabel('X, dimension 1')
ax_s.set_ylabel('Y, dimension 1')
ax_s.set_title('One dimension of each', fontsize=11.5, fontweight='bold')
ax_s.set_aspect('equal', 'box')

corr = np.corrcoef(np.hstack([np.asarray(x), np.asarray(y)]), rowvar=False)
im = ax_c.imshow(corr, cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(im, ax=ax_c, fraction=0.046)
ax_c.axhline(DIM - 0.5, color='k', lw=1)
ax_c.axvline(DIM - 0.5, color='k', lw=1)
ax_c.set_title('Correlation of [X, Y] stacked', fontsize=11.5, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# The off-diagonal blocks carry the coupling. Note that MI measures the total
# dependence across all five dimensions jointly, so no single scatter plot shows
# the whole of it.

# %% [markdown]
# ## 2. One call
#
# The library has a single entry point. `mode='estimate'` trains one critic and
# returns one number.
#
# The `split` argument deserves attention immediately. The estimator trains on
# part of the data and evaluates on a held-out part, and how you divide them
# matters enormously. `Split(mode='random')` shuffles before splitting, which is
# correct **only** when samples are genuinely independent, as they are here.
# `Split(mode='blocked')` is the default and is correct for anything recorded over
# time. Tutorial 3 shows what goes wrong if you get this backwards.

# %%
result = nmi.run(
    x, y, mode='estimate',
    split=nmi.Split(mode='random'),        # correct here: samples are IID
    training=nmi.Training(n_epochs=int(50 * SCALE), patience=20),
    n_workers=1, seed=0, show_progress=False,
)

print(f"true MI      : {TRUE_MI:.3f} bits")
print(f"estimate     : {result.mi_estimate:.3f} bits")
print(f"absolute error: {abs(result.mi_estimate - TRUE_MI):.3f} bits")
# Out:
# true MI      : 2.000 bits
# estimate     : 2.050 bits
# absolute error: 0.050 bits

# %% [markdown]
# ## 3. Which number that is
#
# `result.mi_estimate` is the headline, and it is worth knowing exactly what it
# measures.
#
# The library tracks MI on a held-out test set every epoch and uses that curve to
# choose *when* to stop, picking the epoch where held-out performance peaked. It
# then reports the **training-set** MI at that epoch. So the epoch is chosen
# honestly, on data the critic never trained on, while the reported value is
# computed on data it did.
#
# That makes `mi_estimate` an in-sample number, and in-sample numbers run
# optimistic for the same reason they do anywhere in supervised learning. The
# held-out value sits in `result.details['test_mi']`.

# %%
print(f"mi_estimate (train-side, at the selected epoch): {result.mi_estimate:.3f} bits")
print(f"details['test_mi'] (held out)                  : {result.details['test_mi']:.3f} bits")
print(f"true MI                                        : {TRUE_MI:.3f} bits")
# Out:
# mi_estimate (train-side, at the selected epoch): 2.050 bits
# details['test_mi'] (held out)                  : 1.980 bits
# true MI                                        : 2.000 bits

# %% [markdown]
# Measured on a quantity with an exactly known value of 1.0496 bits, across eight
# independent seeds: `mi_estimate` averaged 1.110 and exceeded the truth in 7 of 8
# runs, while `details['test_mi']` averaged 0.984 and fell below it in 6 of 8.
#
# The held-out number is the one carrying the lower-bound guarantee. The reported
# number is less noisy, which is why it is the default. Use `mi_estimate` for
# routine work and reach for `details['test_mi']` when you want the conservative
# figure or when a claim turns on the exact magnitude. Tutorial 7 covers the
# bias-correction machinery that addresses this properly rather than by choosing
# between the two.

# %% [markdown]
# ## 4. Small samples are unreliable, in both directions
#
# The estimate above came from 5000 samples. Neural estimators need data, and with
# too little the answer can land well off in either direction: the variational
# bound pulls estimates down when the critic is undertrained, while finite-sample
# effects push them up. Which wins depends on the regime.

# %%
sizes = [int(s * SCALE) for s in (100, 300, 500, 1000, 3000, 5000)]
estimates, held_out = [], []

for n in sizes:
    xn, yn = nmi.generators.generate_correlated_gaussians(
        n_samples=n, dim=DIM, mi=TRUE_MI)
    r = nmi.run(xn, yn, mode='estimate', split=nmi.Split(mode='random'),
                training=nmi.Training(n_epochs=int(50 * SCALE), patience=20),
                n_workers=1, seed=0, show_progress=False)
    estimates.append(r.mi_estimate)
    held_out.append(r.details['test_mi'])
    print(f"  n = {n:5d}   estimate = {r.mi_estimate:6.3f}   "
          f"held-out = {r.details['test_mi']:6.3f}   "
          f"error = {r.mi_estimate - TRUE_MI:+.3f}")
# Out:
# <env>/neuralmipaper/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3701: UserWarning: Very few samples detected (100 samples). Neural MI estimators are prone to overfitting at this scale. Consider adding regularisation (Model(dropout=..., norm_layer=...)).
#   exec(code_obj, self.user_global_ns, self.user_ns)
# neural_mi/analysis/task.py:367: UserWarning: batch_size=128 exceeds the 90 training samples available, so it has been capped to 90. Batch size bounds how many contrastive samples each estimate is scored against, and raising it beyond the training-set size has no effect. To change that bound, increase the number of training samples: use a longer recording, a smaller window_size, or a smaller step_size.
#   results = trainer.train(
# ...

# %%
fig, ax = plt.subplots(figsize=(8.5, 4.6))

ax.plot(sizes, estimates, 'o-', color='steelblue', lw=2, ms=7, label='mi_estimate')
ax.plot(sizes, held_out, 's--', color='darkorange', lw=1.8, ms=6,
        label="details['test_mi'] (held out)")
ax.axhline(TRUE_MI, color='seagreen', lw=1.8, label=f'True MI ({TRUE_MI} bits)')
ax.set_xscale('log')
ax.set_xlabel('Number of samples')
ax.set_ylabel('MI (bits)')
ax.set_title('Small samples give unreliable estimates', fontsize=12.5,
             fontweight='bold')
ax.legend()
ax.grid(alpha=0.25)
plt.tight_layout()
plt.show()

# %% [markdown]
# The estimate wanders at small sample sizes and settles as data accumulates. Your
# exact numbers will differ from run to run, which is the point: a single estimate
# on limited data is not a reliable measurement. Tutorial 7 turns a noisy point
# estimate into a bias-corrected value with an interval.

# %% [markdown]
# ## 5. Did you need a neural estimator?
#
# A fair question, and the honest answer is that for the data above you did not.
#
# **KSG** (Kraskov, Stoegbauer and Grassberger) estimates mutual information from
# k-nearest-neighbour distances. No training, no architecture, no epochs, one
# parameter. It runs in a fraction of a second. When it works it is the better
# tool, and it is worth knowing where that stops.
#
# First, confirm it works.

# %%
from scipy.spatial import cKDTree
from scipy.special import digamma


def ksg_mi(x, y, k=3):
    '''Kraskov-Stoegbauer-Grassberger estimator 1, in bits.'''
    x, y = np.asarray(x, dtype=float), np.asarray(y, dtype=float)
    n = x.shape[0]
    d_joint = cKDTree(np.hstack([x, y])).query(np.hstack([x, y]),
                                               k=k + 1, p=np.inf)[0][:, k]
    nx = cKDTree(x).query_ball_point(x, r=d_joint - 1e-12, p=np.inf,
                                     return_length=True) - 1
    ny = cKDTree(y).query_ball_point(y, r=d_joint - 1e-12, p=np.inf,
                                     return_length=True) - 1
    return max(0.0, (digamma(k) + digamma(n)
                     - np.mean(digamma(nx + 1) + digamma(ny + 1))) / np.log(2))


print(f"{'true MI':>9} {'dim':>5} {'KSG':>8} {'error':>8}")
for true_mi in (0.5, 1.0, 2.0):
    for dim in (1, 2):
        xa, ya = nmi.generators.generate_correlated_gaussians(
            n_samples=4000, dim=dim, mi=true_mi, use_torch=False)
        est = ksg_mi(xa, ya)
        print(f"{true_mi:9.2f} {dim:5d} {est:8.3f} {est - true_mi:+8.3f}")
# Out:
#   true MI   dim      KSG    error
#      0.50     1    0.496   -0.004
#      0.50     2    0.477   -0.023
#      1.00     1    0.998   -0.002
#      1.00     2    1.032   +0.032
#      2.00     1    1.975   -0.025
#      2.00     2    1.963   -0.037

# %% [markdown]
# Accurate to a few hundredths of a bit, in milliseconds. If your problem looks
# like this, use KSG.
#
# Now the case where it stops working, and it is the case neural recordings
# usually present. Take a **2-dimensional** informative signal and pad it with
# dimensions carrying nothing at all. The true MI never changes, because the
# padding is independent of everything, and the signal itself is untouched.

# %%
def buried_signal(n_noise, n_samples=int(8000 * SCALE), true_mi=2.0, seed=0):
    '''A 2-D informative signal padded with `n_noise` uninformative dimensions.'''
    rng = np.random.default_rng(seed)
    xl, yl = nmi.generators.generate_correlated_gaussians(
        n_samples=n_samples, dim=2, mi=true_mi, use_torch=False)
    xl, yl = np.asarray(xl), np.asarray(yl)
    wx, wy = rng.normal(size=(2, 4)), rng.normal(size=(2, 4))
    sx, sy = np.tanh(xl @ wx), np.tanh(yl @ wy)
    if n_noise:
        sx = np.hstack([sx, rng.normal(size=(len(sx), n_noise))])
        sy = np.hstack([sy, rng.normal(size=(len(sy), n_noise))])
    return sx.astype('float32'), sy.astype('float32')


noise_dims = [0, 8, 48, 198]
ksg_curve, neural_curve, total_dims = [], [], []

for n_noise in noise_dims:
    xb, yb = buried_signal(n_noise)
    total_dims.append(xb.shape[1])
    ksg_curve.append(ksg_mi(xb, yb))
    r = nmi.run(xb, yb, mode='estimate', split=nmi.Split(mode='random'),
                model=nmi.Model(embedding_dim=32, hidden_dim=256, n_layers=3),
                training=nmi.Training(n_epochs=int(100 * SCALE), patience=35,
                                      batch_size=256),
                n_workers=1, seed=0, show_progress=False)
    neural_curve.append(r.mi_estimate)
    print(f"  {n_noise:4d} uninformative dims  (total {xb.shape[1]:4d})   "
          f"KSG = {ksg_curve[-1]:6.3f}   neural = {neural_curve[-1]:6.3f}")
# Out:
# neural_mi/analysis/task.py:367: UserWarning: Training completed all 100 epoch(s) without early stopping, and the best (smoothed) test MI occurred at the final epoch. MI may still have been increasing when training stopped, so the reported estimate could be an under-trained lower bound. Consider increasing n_epochs (or lowering patience to enable early stopping).
#   results = trainer.train(
#      0 uninformative dims  (total    4)   KSG =  1.887   neural =  1.840
#      8 uninformative dims  (total   12)   KSG =  0.310   neural =  1.847
#     48 uninformative dims  (total   52)   KSG =  0.003   neural =  0.878
#    198 uninformative dims  (total  202)   KSG =  0.003   neural =  0.897

# %%
fig, ax = plt.subplots(figsize=(8.5, 4.8))

ax.plot(total_dims, ksg_curve, 'o-', color='#b4552d', lw=2, ms=8, label='KSG')
ax.plot(total_dims, neural_curve, 's-', color='steelblue', lw=2, ms=8,
        label='Neural (this library)')
ax.axhline(2.0, color='seagreen', lw=1.8, ls='--', label='True MI (2.0 bits)')

ax.set_xscale('log')
ax.set_xlabel('Total dimensions (2 informative, the rest carrying nothing)')
ax.set_ylabel('Estimated MI (bits)')
ax.set_title('KSG degrades as uninformative dimensions are added',
             fontsize=12.5, fontweight='bold')
ax.legend()
ax.grid(alpha=0.25)
plt.tight_layout()
plt.show()

# %% [markdown]
# Read that table carefully, because it says two things and only one of them is
# the headline.
#
# **KSG collapses.** From 1.89 bits with no padding to 0.003 bits at 202
# dimensions, which is roughly one part in six hundred of the truth. The
# informative content never changed. All that changed is how much irrelevant
# company it keeps.
#
# **The neural estimator degrades too.** It holds 1.85 bits through 12 dimensions,
# then falls to about 0.9 at 52 and stays there. That is 45% of the truth rather
# than the 100% you might hope for. Neither estimator is immune, and a tutorial
# claiming otherwise would be selling you something.
#
# The difference is one of degree, and the degree is large: at 202 dimensions the
# neural estimate retains roughly 45% of the information while KSG retains 0.15%.
# That is the argument, and it is strong enough without exaggeration.
#
# **Why KSG fails.** It measures distances between points and asks who is near
# whom. Dimensions carrying no information still contribute to those distances, so
# neighbourhoods stop reflecting the signal and start reflecting the padding. With
# 198 padding dimensions against 4 informative ones, nearly all of any distance is
# noise.
#
# **Why the neural estimator degrades more gracefully.** It learns an encoder, so
# it can discover which directions matter and discard the rest. But it has to
# *learn* that from finite data, and the more irrelevant directions there are, the
# harder that is. The failure mode is different, and so is the remedy: KSG cannot
# be helped by more samples in this regime, whereas the neural estimator can.
#
# **Be careful with the lesson.** The failure is about **uninformative dimensions
# swamping distance-based neighbourhoods**, not about high dimension as such. A
# counterexample makes the distinction concrete: a 2-dimensional signal embedded
# smoothly into 100 dimensions, with no uninformative padding, is estimated by KSG
# to within 0.09 bits, because the neighbourhoods still track the 2-dimensional
# structure. Dimension alone does not defeat it; irrelevant dimension does.
#
# This is exactly the situation a population recording presents. A few hundred
# channels, with the behaviourally relevant structure living in a handful of
# directions and the rest contributing variance you do not care about.

# %% [markdown]
# ## 6. Key Takeaways
#
# - **`nmi.run()` is the entry point**, and `mode='estimate'` gives one number
#   from one trained critic.
#
# - **`mi_estimate` is an in-sample number**, the train-side MI at an epoch chosen
#   on held-out data, so it runs slightly optimistic.
#   `details['test_mi']` is the held-out value and carries the lower-bound
#   behaviour.
#
# - **`Split(mode='random')` only for genuinely IID samples.** Anything recorded
#   over time needs `Split(mode='blocked')`, which is the default. Tutorial 3
#   shows the cost of getting this wrong.
#
# - **Small samples are unreliable in both directions**, so treat a single
#   estimate on limited data as a hint rather than a measurement.
#
# - **Use KSG when your data is low-dimensional.** It is faster, simpler and
#   accurate there. The neural estimator earns its cost when the informative
#   structure is buried among dimensions that carry nothing, which is the usual
#   case for population recordings. Both degrade as irrelevant dimensions pile up;
#   the neural one degrades far more slowly, and unlike KSG it can be helped by
#   collecting more data.

# %% [markdown]
# ## Common Mistakes
#
# 1. **Passing `(n_channels, n_samples)`.** The library expects samples first.
#    Print `x.shape` and confirm the leading dimension is your observation count.
#
# 2. **Using a random split on recorded data.** Adjacent samples in a recording
#    are correlated, so a random split puts near-copies on both sides and inflates
#    the result. Tutorial 3 measures how much.
#
# 3. **Reporting `mi_estimate` when the claim needs a lower bound.** Use
#    `details['test_mi']`, or better, the bias-corrected estimate from Tutorial 7.
#
# 4. **Reaching for a neural estimator on 2-dimensional data.** KSG is faster and
#    at least as accurate there. Complexity should be earned.
#
# 5. **Reading one small-sample estimate as a measurement.** Rerun it with a
#    different seed before believing it.

# %% [markdown]
# ## What's Next
#
# **Tutorial 2** moves from this clean IID matrix to real neural recording
# formats: continuous traces, raw spike times, pre-binned counts and categorical
# states, and how the library turns each into the one tensor shape its models
# consume.
#
# The assumption quietly made throughout this notebook is that "the mutual
# information of X and Y" names a single number. For IID data it does. For a time
# series it does not, and **Tutorial 4** is where that is resolved.
