# %% [markdown]
# # Tutorial 1: A First MI Estimate
#
# Welcome to the `NeuralMI` library! This first tutorial covers the most basic use case: getting a single, quick estimate of mutual information (MI) between two variables.
#
# Our goal is to introduce the main `nmi.run` function and show how to interpret its output. We'll use a simple synthetic dataset where the true MI is known, allowing us to verify that our estimate is accurate.
#
# Here we are estimating MI for a simple, common case: **Independent and Identically Distributed (IID) data**.
#
# IID means that each data sample is independent of the others. There is no temporal order or sequence. This is a crucial concept, as it determines the correct way to split our data for model training and validation.

# %% [markdown]
# ## 1. Imports
#
# First, let's import the necessary libraries. We'll need `numpy` and `matplotlib` for data manipulation and visualization and, most importantly, our `neural_mi` library, which we import as `nmi`.

# %%
import numpy as np
import matplotlib.pyplot as plt
import neural_mi as nmi

# %% [markdown]
# ## 2. Generating the Data
#
# We will use the `generate_correlated_gaussians` function, which creates two multidimensional Gaussian variables, `X` and `Y`, with a precisely specified mutual information in **bits**.
#
# The library expects raw data in the format `(n_samples, n_channels)`. Our data generator produces data of shape `(n_samples, n_features)`, so we are good.

# %%
# --- Dataset Parameters ---
n_samples = 5000
dim = 5
ground_truth_mi_bits = 3.0

# --- Generate Raw 2D Data ---
# This creates data of shape (n_samples, dim).
x, y = nmi.generators.generate_correlated_gaussians(
    n_samples=n_samples, 
    dim=dim, 
    mi=ground_truth_mi_bits
)


print(f"X data shape: {x.shape}")
print(f"Y data shape: {y.shape}")
# Out:
# X data shape: torch.Size([5000, 5])
# Y data shape: torch.Size([5000, 5])

# %% [markdown]
# Visualize the data, the data is simply pairwise correlated gaussians, where there's a direct mapping between correlation and MI.

# %%
# Plot all dimensions of the data against each other:
fig, axes = plt.subplots(dim, dim, figsize=(10, 10))
for i in range(dim):
    for j in range(dim):
        axes[i, j].scatter(x[:, i], y[:, j], alpha=0.5, s=10)
        axes[i, j].set_xlabel(f"X dim {i+1}")
        axes[i, j].set_ylabel(f"Y dim {j+1}")
plt.tight_layout()

# Plot the correlation matrix of the data:
fig, axes = plt.subplots(1, 1, figsize=(5, 5))
im = axes.imshow(np.corrcoef(x, y, rowvar=False), vmin=-1, vmax=1, cmap='coolwarm')
axes.set_title("Correlation Matrix of X and Y")
plt.colorbar(im, ax=axes)
plt.tight_layout()

# %% [markdown]
# ## 3. The `nmi.run` Function: Modes of Analysis
#
# The `nmi.run` function is the heart of the library. It can be configured to run in several 'modes', each designed for a different kind of analysis. For this tutorial, we will use the simplest mode, `'estimate'`, but it's good to be aware of the others, which we will cover in future tutorials:
#
# - **`'estimate'`**:  A single, quick MI estimate. Perfect for getting a first look at your data.
# - **`'sweep'`**:  An exploratory sweep over a grid of hyperparameters (like `window_size`).
# - **`'rigorous'`**: The full, bias-corrected MI estimation workflow for publication-ready results.
# - **`'dimensionality'`**: Estimates the latent dimensionality of a single variable X using spectral SVD metrics.
# - **`'lag'`**:  Estimates MI across a range of time lags between X and Y.
# - **`'precision'`**: Estimates the temporal precision of a representation using a "Train Once, Evaluate Many" paradigm.

# %% [markdown]
# ## 4. Defining the Analysis Parameters
#
# To run an estimation, we need to provide **`base_params`**: These control the neural network model and the training process. Here we define the architecture (`embedding_dim`, `hidden_dim`, `n_layers`) and training limits (`n_epochs`, `patience`, `learning_rate`).

# %%
# Basic model and training parameters
base_params = {
    # 'n_epochs': 100, 
    # 'learning_rate': 5e-4,
    # 'patience': 25,
    # 'batch_size': 128,
    # 'embedding_dim': 16, 
    # 'hidden_dim': 128, 
    # 'n_layers': 2,
}

# %% [markdown]
# ## 5. Running the MI Estimation
#
# Now we call the main `nmi.run` function. We specify `mode='estimate'` for a single, quick run, we pass the `base_params` and specify the `split_mode='random'` for train and test splitting. We pass `None` for `processor_type_x` and `processor_type_y` because we don't want to perform any processing on the data.

# %%
results = nmi.run(
    x_data=x, 
    y_data=y,
    # processor_type_x=None,
    # processor_type_y=None,
    mode='estimate',
    # base_params=base_params,
    # verbose=True,
    split_mode='random',  # For IID data
)
# Out:
# 2026-03-02 09:15:37 - neural_mi - WARNING - Pre-processed data detected. Skipping compatibility check. Ensure X and Y have compatible representations.
# 2026-03-02 09:15:37 - neural_mi - INFO - Created PairedDataset
# 2026-03-02 09:15:37 - neural_mi - INFO - Starting parameter sweep sequentially (n_workers=1)...
# Sequential Sweep Progress:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-03-02 09:15:37 - neural_mi - WARNING - Pre-processed data detected. Skipping compatibility check. Ensure X and Y have compatible representations.
# 2026-03-02 09:15:37 - neural_mi - INFO - Created PairedDataset
# Run 061217ad-81c1-4173-bddf-39f41fcc7775_c0:   0%|          | 0/50 [00:00<?, ?it/s]
# 2026-03-02 09:15:42 - neural_mi - INFO - Parameter sweep finished.

# %% [markdown]
# ## 6. Interpreting the Results
#
# The `nmi.run` function returns a special `Results` object that holds all the information from the analysis. For `'estimate'` mode, the most important attribute is `mi_estimate`.

# %%
estimated_mi_bits = results.mi_estimate

print(f"\n--- Results ---")
print(f"Ground Truth MI:  {ground_truth_mi_bits:.3f} bits")
print(f"Estimated MI:     {estimated_mi_bits:.3f} bits")
print(f"Estimation Error: {abs(estimated_mi_bits - ground_truth_mi_bits):.3f} bits")
# Out:
# --- Results ---
# Ground Truth MI:  3.000 bits
# Estimated MI:     2.781 bits
# Estimation Error: 0.219 bits

# %% [markdown]
# ## 7. Conclusion
#
# Success! The estimated MI is very close to the ground truth value (try to increase the number of samples!). You have successfully used the `nmi.run` function to get your first MI estimate using the updated processing pipelines.
#
# In the next tutorial, we'll dive deeper into how the library handles more complex, realistic neural data formats, including continuous traces and discrete spike times.
